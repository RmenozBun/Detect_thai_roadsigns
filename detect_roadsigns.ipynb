# %%
import cv2
import numpy as np
import random
from ultralytics import YOLO

# %%
#model = YOLO("C:/Users/uSeR/Documents/Detect_thai_roadsigns/runs/detect/train/weights/best.pt")

# %%
model = YOLO("yolov8n.pt")

# %%
#model.train(data="C:/Users/uSeR/Documents/Detect_thai_roadsigns/data.yaml",epochs=1000,task='detect',batch=16,imgsz=640,device=0,workers=8)

# %%
#model.train(data="data.yaml",epochs=100)

# %%
#model.train(data="D:\Animal_Guessing_Game\venv\detect_cartoon_animal\data.yaml",epochs=1000,task='detect',batch=16,imgsz=640,device=0,workers=8)

# %%
model.train(
    data="D:/Animal_Guessing_Game/venv/detect_cartoon_animal/data.yaml",
    epochs=1000,
    task='detect',
    batch=16,
    imgsz=[570, 798],  # [width, height]
    device='0',  # ถ้าไม่มี GPU
    workers=8
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.train(
#       2     data="D:/Animal_Guessing_Game/venv/detect_cartoon_animal/data.yaml",
#       3     epochs=1000,
#       4     task='detect',
#       5     batch=16,
#       6     imgsz=[570, 798],  # [width, height]
#       7     device='0',  # ถ้าไม่มี GPU
#       8     workers=8
#       9 )
#
# NameError: name 'model' is not defined

# %%
# traffic_signs = ['buses_only', 'give_way', 'no_entry', 'no_honking', 'no_overtaking', 'no_parking', 'other_danger', 'pedestrian_crossing', 'slippery_road', 'stop']
# current_sign = random.choice(traffic_signs)

# def new_task():
#     return random.choice(traffic_signs)

# cap = cv2.VideoCapture(0)

# score = 0

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break
    
#     results = model(frame)

#     for result in results:
#         boxes = result.boxes
#         for box in boxes:
#             x1, y1, x2, y2 = map(int, box.xyxy[0])
#             conf = box.conf[0]
#             class_id = int(box.cls[0])
#             label = traffic_signs[class_id]
            
#             cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
#             cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

#             if label == current_sign:
#                 score += 1
#                 current_sign = new_task()

#     cv2.putText(frame, f'Guessing Questions: {current_sign}', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)
#     cv2.putText(frame, f'Score: {score}', (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

#     cv2.imshow('Traffic Sign Detection', frame)

#     if score == 10:
#         break

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 give_way, 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 give_way, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 give_way, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 give_way, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 give_way, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 give_way, 3.0ms
# Speed: 1.0ms preprocess, 3.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 give_way, 4.0ms
# Speed: 1.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 give_way, 3.0ms
# ...
